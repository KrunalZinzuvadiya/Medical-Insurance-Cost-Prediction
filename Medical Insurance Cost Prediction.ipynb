# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
df = pd.read_csv("F:\\Project\\Data\\medical_insurance.csv")
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 2767   47  female  45.320         1     no  southeast   8569.86180
# 2768   21  female  34.600         0     no  southwest   2020.17700
# 2769   19    male  26.030         1    yes  northwest  16450.89470
# 2770   23    male  18.715         0     no  northwest  21595.38229
# 2771   54    male  31.600         0     no  southwest   9850.43200
#
# [2772 rows x 7 columns]

# %%
df.shape
# Out:
# (2772, 7)

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2772 entries, 0 to 2771
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       2772 non-null   int64
#  1   sex       2772 non-null   object
#  2   bmi       2772 non-null   float64
#  3   children  2772 non-null   int64
#  4   smoker    2772 non-null   object
#  5   region    2772 non-null   object
#  6   charges   2772 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 151.7+ KB

# %%
df.describe(include = 'all')
# Out:
#                 age   sex          bmi     children smoker     region  \
# count   2772.000000  2772  2772.000000  2772.000000   2772       2772
# unique          NaN     2          NaN          NaN      2          4
# top             NaN  male          NaN          NaN     no  southeast
# freq            NaN  1406          NaN          NaN   2208        766
# mean      39.109668   NaN    30.701349     1.101732    NaN        NaN
# std       14.081459   NaN     6.129449     1.214806    NaN        NaN
# min       18.000000   NaN    15.960000     0.000000    NaN        NaN
# 25%       26.000000   NaN    26.220000     0.000000    NaN        NaN
# 50%       39.000000   NaN    30.447500     1.000000    NaN        NaN
# 75%       51.000000   NaN    34.770000     2.000000    NaN        NaN
# max       64.000000   NaN    53.130000     5.000000    NaN        NaN
#
#              charges
# count    2772.000000
# unique           NaN
# top              NaN
# freq             NaN
# ...

# %%
#Plot the graph
sns.distplot(df['age'])
plt.title('AGe DIstribution')
plt.show()
# Out:
# C:\Users\jalpa\AppData\Local\Temp\ipykernel_27064\3730511504.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['age'])

# %%
#plot the gender
sns.countplot(df['sex'])
plt.show()

# %%
sns.pairplot(df, hue = 'region')
plt.show()
# Out:
# c:\Users\jalpa\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\jalpa\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\jalpa\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# ...

# %%
#plot the gender
sns.countplot(df['region'])
plt.show()

# %%
#plot the gender
sns.countplot(df['smoker'])
plt.show()

# %%
sns.regplot(x = 'age', y = 'charges', data = df)
plt.show()

# %%
#plot
sns.distplot(df['bmi'])
plt.show()
# Out:
# C:\Users\jalpa\AppData\Local\Temp\ipykernel_27064\2734533250.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bmi'])

# %%
df['region'].value_counts()
# Out:
# region
# southeast    766
# southwest    684
# northwest    664
# northeast    658
# Name: count, dtype: int64

# %%
df.replace({'sex':{'male':0,'female':1}}, inplace = True)
# Out:
# C:\Users\jalpa\AppData\Local\Temp\ipykernel_27064\240408948.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({'sex':{'male':0,'female':1}}, inplace = True)

# %%
df
# Out:
#       age  sex     bmi  children smoker     region      charges
# 0      19    1  27.900         0    yes  southwest  16884.92400
# 1      18    0  33.770         1     no  southeast   1725.55230
# 2      28    0  33.000         3     no  southeast   4449.46200
# 3      33    0  22.705         0     no  northwest  21984.47061
# 4      32    0  28.880         0     no  northwest   3866.85520
# ...   ...  ...     ...       ...    ...        ...          ...
# 2767   47    1  45.320         1     no  southeast   8569.86180
# 2768   21    1  34.600         0     no  southwest   2020.17700
# 2769   19    0  26.030         1    yes  northwest  16450.89470
# 2770   23    0  18.715         0     no  northwest  21595.38229
# 2771   54    0  31.600         0     no  southwest   9850.43200
#
# [2772 rows x 7 columns]

# %%
df.replace({'smoker' : {'yes' : 1, 'no' : 0}}, inplace = True)
df
# Out:
#       age  sex     bmi  children  smoker     region      charges
# 0      19    1  27.900         0       1  southwest  16884.92400
# 1      18    0  33.770         1       0  southeast   1725.55230
# 2      28    0  33.000         3       0  southeast   4449.46200
# 3      33    0  22.705         0       0  northwest  21984.47061
# 4      32    0  28.880         0       0  northwest   3866.85520
# ...   ...  ...     ...       ...     ...        ...          ...
# 2767   47    1  45.320         1       0  southeast   8569.86180
# 2768   21    1  34.600         0       0  southwest   2020.17700
# 2769   19    0  26.030         1       1  northwest  16450.89470
# 2770   23    0  18.715         0       0  northwest  21595.38229
# 2771   54    0  31.600         0       0  southwest   9850.43200
#
# [2772 rows x 7 columns]

# %%
df.replace({'region' : {'southeast' :0, 'southwest' : 1, 'northeast':2, 'northwest':3}}, inplace = True)
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    1  27.900         0       1       1  16884.92400
# 1      18    0  33.770         1       0       0   1725.55230
# 2      28    0  33.000         3       0       0   4449.46200
# 3      33    0  22.705         0       0       3  21984.47061
# 4      32    0  28.880         0       0       3   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 2767   47    1  45.320         1       0       0   8569.86180
# 2768   21    1  34.600         0       0       1   2020.17700
# 2769   19    0  26.030         1       1       3  16450.89470
# 2770   23    0  18.715         0       0       3  21595.38229
# 2771   54    0  31.600         0       0       1   9850.43200
#
# [2772 rows x 7 columns]

# %%
#assign variable
x = df.drop(columns = 'charges' , axis = 1)
y = df['charges']

# %%
x
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    1  27.900         0       1       1
# 1      18    0  33.770         1       0       0
# 2      28    0  33.000         3       0       0
# 3      33    0  22.705         0       0       3
# 4      32    0  28.880         0       0       3
# ...   ...  ...     ...       ...     ...     ...
# 2767   47    1  45.320         1       0       0
# 2768   21    1  34.600         0       0       1
# 2769   19    0  26.030         1       1       3
# 2770   23    0  18.715         0       0       3
# 2771   54    0  31.600         0       0       1
#
# [2772 rows x 6 columns]

# %%
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 2767     8569.86180
# 2768     2020.17700
# 2769    16450.89470
# 2770    21595.38229
# 2771     9850.43200
# Name: charges, Length: 2772, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size =0.2, random_state = 202)

# %%
x_train.shape
# Out:
# (2217, 6)

# %%
y_train.shape
# Out:
# (2217,)

# %%
x_test.shape
# Out:
# (555, 6)

# %%
y_test.shape
# Out:
# (555,)

# %%
reg = LinearRegression()
reg
# Out:
# LinearRegression()

# %%
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
train_prediction = reg.predict(x_train)
train_prediction
# Out:
# array([ 6524.67443568, 10932.38836528,   536.48182417, ...,
#         9396.34355374, 14502.16129207,  4729.55123981])

# %%
r2_train = metrics.r2_score(y_train, train_prediction)
r2_train
# Out:
# 0.7442522790395278

# %%
reg.score(x,y)
# Out:
# 0.7503620850251453

# %%
test_prediction = reg.predict(x_test)
test_prediction
# Out:
# array([ 5484.52415222,  6083.87531148, 36930.97219535, 15558.06328107,
#        14064.66078696, 11094.27342304,  2379.94284092,  7264.00848253,
#         2614.5240302 ,  3993.20808873,  3632.48966424,  9527.98589421,
#         8424.07165873, 10529.04851148,  2276.24919512,  6927.53326117,
#         9095.16950165, 29814.39580933,  -141.28074682, 34838.58867428,
#         5208.34002349, 35605.70331267,  3638.28834789,  5893.42145401,
#         9207.11551478, 11650.40193859,  -782.43468129, 27844.69762997,
#        11459.54065335,  8071.99297017, 12952.11729037,  1662.52038717,
#        11667.25270068, 14966.63175423, 35605.70331267, 35631.51422875,
#         9834.98264677,  4389.88412119,  6132.3204646 ,  6816.79594685,
#        15146.89568153,  3987.37137823,  9477.94403032, 15715.99049346,
#         7820.07047   ,  8208.55360542, 28942.93775035, 36805.31865943,
#        11841.48862649,  2965.55828201,  7693.84442556,  8208.55360542,
# ...

# %%
r2_score_test = metrics.r2_score(y_test , test_prediction)
r2_score_test
# Out:
# 0.7748998380334478

# %%
df.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    1  27.900         0       1       1  16884.92400
# 1   18    0  33.770         1       0       0   1725.55230
# 2   28    0  33.000         3       0       0   4449.46200
# 3   33    0  22.705         0       0       3  21984.47061
# 4   32    0  28.880         0       0       3   3866.85520

# %%
input_sample = (28, 1, 26, 2, 0, 2)
input_sample_array = np.array(input_sample)
input_sample_array = input_sample_array.reshape(1,-1)
input_sample_array
# Out:
# array([[28,  1, 26,  2,  0,  2]])

# %%
new_predict = reg.predict(input_sample_array)
new_predict
# Out:
# C:\Users\jalpa\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([4681.13101023])

# %%
print('Medical Insurance cost for given sample is' , new_predict)
# Out:
# Medical Insurance cost for given sample is [4681.13101023]

# %% [markdown]
# # Thank You
